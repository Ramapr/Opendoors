# %% [markdown]
# ## Для запуска данного кода есть два варианта:
# 1) В облаке от Google создать файл и скопировать код туда (https://colab.research.google.com/notebooks/welcome.ipynb)
# 2) Установить среду разработки и библиотеки на свой ПК

# %% [markdown]
# ### Установка на ПК для Windows:
# - идем на https://repo.anaconda.com/archive/ и выбираем дистрибутив Anaconda3-5.2.0-Windows
# - устанавливаем программу
# - после установки находим программу Anaconda Prompt
# - в командной строке прописываем __conda install tensorflow==1.8__
# - после установки tensorflow пишем __conda install -c conda-forge keras__
# - __done!__ запускаем Jupyter Notebook -> new -> Python3

# %%
from keras.applications.vgg16 import VGG16
from keras.preprocessing import image
from keras.applications.vgg16 import preprocess_input, decode_predictions
import matplotlib.pyplot as plt
import numpy as np
# Out:
# C:\Users\SSS4\Anaconda3\lib\site-packages\h5py\__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
model = VGG16(weights='imagenet')

# %%
img = image.load_img('img4.jpg', target_size=(224, 224))
x = image.img_to_array(img)
x = np.expand_dims(x, axis=0)
x = preprocess_input(x)

preds = model.predict(x)

plt.imshow(img)
print('Результаты распознавания:', decode_predictions(preds, top=3)[0])
# Out:
# Результаты распознавания: [('n01855672', 'goose', 0.9989281), ('n01514859', 'hen', 0.0005936471), ('n01847000', 'drake', 0.00021484487)]
